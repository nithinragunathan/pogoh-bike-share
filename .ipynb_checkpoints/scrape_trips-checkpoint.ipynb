# %%
import numpy as np
import pandas as pd
import requests
from datetime import datetime
from dateutil.parser import parse
import urllib.request
from bs4 import BeautifulSoup

# %%
standard_schema =  ['ride_id', '' 'duration', 'start_time', 'end_time',
                    'start_station_name', 'end_station_name', 'ridertype', 'bike_system']

pogoh_transforms = "['PO-' + x['ride_id'],int(x['Duration']), parse(str(x['Start Date'])),parse(str(x['End Date'])),x['Start Station Name'],x['End Station Name'],x['Rider Type'],'POGOH']"


healthyride_transforms = "['HR-' + x['ride_id'], int(x['Tripduration']), parse(x['Starttime']),parse(x['Stoptime']),x['From station name'],x['To station name'],x['Usertype'],'Healthy Ride']"

# %%
pd.read_csv('https://data.wprdc.org/dataset/bfbaa051-677c-445f-95c5-f9ca129accd4/resource/f8e0d66b-3958-4c8c-97d0-4351b9dfb222/download/healthy-ride-rentals-2018-q1.csv')
# Out:
#        Trip id        Starttime         Stoptime  Bikeid  Tripduration  \
# 0     41489490   1/1/2018 17:19   1/1/2018 17:24   70259           276
# 1     41491355    1/2/2018 7:28   1/2/2018 10:25   70213         10575
# 2     41491375    1/2/2018 7:32    1/2/2018 7:59   70114          1640
# 3     41491450    1/2/2018 7:45   1/2/2018 10:18   70252          9172
# 4     41492051    1/2/2018 9:09    1/2/2018 9:10   70481            61
# ...        ...              ...              ...     ...           ...
# 5181  42771071  3/31/2018 23:05  3/31/2018 23:09   70116           198
# 5182  42771073  3/31/2018 23:06  3/31/2018 23:21   70372           866
# 5183  42771083  3/31/2018 23:10  3/31/2018 23:14   70298           218
# 5184  42771105  3/31/2018 23:19  3/31/2018 23:30   70301           707
# 5185  42771108  3/31/2018 23:20  3/31/2018 23:29   70320           536
#
#       From station id                                  From station name  \
# 0                1022  Liberty Ave & S Millvale Ave (West Penn Hospital)
# 1                1040  O'Hara St and University Place (Soldiers and S...
# 2                1049                            S 12th St & E Carson St
# 3                1002                                Third Ave & Wood St
# 4                1048                              S 18th St & Sidney St
# ...               ...                                                ...
# 5181             1008                      Centre Ave & PPG Paints Arena
# 5182             1033                              Ivy St & Walnut St
# 5183             1033                              Ivy St & Walnut St
# 5184             1043                        S Millvale Ave & Centre Ave
# 5185             1043                        S Millvale Ave & Centre Ave
#
#       To station id                              To station name    Usertype
# 0              1023                      Liberty Ave & Baum Blvd  Subscriber
# 1              1037                        Frew St & Schenley Dr  Subscriber
# 2              1049                      S 12th St & E Carson St  Subscriber
# 3              1009                           12th St & Penn Ave  Subscriber
# 4              1048                        S 18th St & Sidney St  Subscriber
# ...             ...                                          ...         ...
# 5181           1006  Ross St & Sixth Ave (Steel Plaza T Station)  Subscriber
# 5182           1020                             42nd & Penn Ave.    Customer
# 5183           1032                       Walnut St & College St  Subscriber
# 5184           1031                 Maryland Ave & Ellsworth Ave  Subscriber
# 5185           1031                 Maryland Ave & Ellsworth Ave  Subscriber
#
# [5186 rows x 10 columns]

# %%
def get_trips(url, transforms):
    if url[-4:] == 'xlsx':
        df = pd.read_excel(url)
        df['ride_id'] = [url.split('/')[-1][:8] + '-' + str(x) for x in range(len(df))]
    elif url[-3:] == 'csv':
        df = pd.read_csv(url)
        df['ride_id'] = [url[-10:-3] + '-' + str(x) for x in range(len(df))]
    return df.apply(lambda x: pd.Series(eval(transforms), index = standard_schema), axis = 1)

# %%
resource_ids = set()
for link in soup.find_all('a'):
    href = link.get('href')
    if href[:31] == 'https://data.wprdc.org/dataset/':
        resource_ids.add(href)
resource_lst = list(resource_ids)
#print(resource_lst)



pogoh_df = pd.DataFrame()

for resource in resource_lst:
    url = resource
    pogoh_df = pd.concat([pogoh_df, get_trips(url, pogoh_transforms)], ignore_index=True)
    print('finished ', url, '\n', len(pogoh_df))
# Out:
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/8e8a5cd9-943e-4d21-a7ed-05f865dd0038/download/apr-2023.xlsx
#  11351
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/1744cd4a-13cf-46de-b773-57f528ee9705/download/july-2022.xlsx
#  20427
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/2cd57068-5498-4b47-b2d3-512d3cdb1e0c/download/may-2022.xlsx
#  26546
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/e2c446b7-b0f5-43d5-87ac-f4b252f27aa3/download/july-2023.xlsx
#  44792
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/4574cdf1-e65a-42df-8ede-eadd4548660a/download/november-2023.xlsx
#  70595
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/a4598299-e02a-43a3-901f-dff08630e96e/download/may-2024.xlsx
#  102341
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/a82c7c20-2c88-4de6-a3db-da1b4d64fe13/download/october-2023.xlsx
#  140426
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/a4f35db1-f120-45ea-a6ee-353e65ce766c/download/february-2024.xlsx
#  165778
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/78ec9f4b-f99e-4995-8a20-2a1e075d63db/download/may-2023.xlsx
#  177759
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/b006e671-5661-4b9c-8eca-1351598804c1/download/december-2023.xlsx
#  193900
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/6ab3626b-b640-41b7-aed8-f3359495a695/download/june-2022.xlsx
#  203189
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/5b44e019-5480-4dcc-aac3-a5f6a624ee53/download/october-2022.xlsx
#  214512
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/115f1654-9757-4705-9ca2-9e8573b3012a/download/august-2022.xlsx
#  225796
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/f3c25fad-372b-4ded-9aab-2f7ae75b9008/download/december-2022.xlsx
#  229487
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/97ba8ceb-a39b-49a1-a7fb-b26aca69c0f4/download/november-2022.xlsx
#  236905
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/cfd4c472-d019-4f25-87ab-4fad1936f127/download/february-2023.xlsx
#  242591
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/0814f43e-bf31-4efd-a2d6-ab48402106d4/download/april-2024.xlsx
#  279358
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/1688f127-e894-4134-ac91-342c988a772c/download/september-2022.xlsx
#  293491
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/a05520d3-cdf1-4b52-aa47-238731c1c32c/download/june-2024.xlsx
#  329132
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/b486bf17-5fa0-4311-b256-9fb354f0f827/download/january-2023.xlsx
#  332961
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/f1ba1ba5-f4f0-449e-af37-36d021ea7223/download/september-2023.xlsx
#  369858
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/49bd4cba-5361-4375-a789-210dd4f7903b/download/march-2023.xlsx
#  375707
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/79e585fd-c139-4eb2-9cc9-5b72de6803de/download/january-2024.xlsx
#  390144
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/e4f6d854-e40a-4f16-8bdf-255c912b4cfd/download/august-2023.xlsx
#  414010
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/01a59873-8f16-428d-a77c-adbc7c86edb8/download/march-2024.xlsx
#  441427
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/a6bde28d-e11b-4854-b3b0-d4a851f6ee3a/download/june-2023.xlsx
#  454939
# '\n    try:\n        new = get_trips(url, pogoh_transforms)\n        df = pd.concat([df, new], axis = 0)\n    except:\n        print()\n    print(df.head())\n'

# %%
URL = "https://data.wprdc.org/dataset/healthyride-trip-data"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-265-cd53ee46fff4> in <module>
#      16 for resource in resource_lst:
#      17     url = resource
# ---> 18     hr_df = pd.concat([hr_df, get_trips(url, healthyride_transforms)], ignore_index=True)
#      19     print('finished ', url, '\n', len(hr_df))
#
# <ipython-input-262-53e7a501a864> in get_trips(url, transforms)
#       7         df['ride_id'] = [url[-10:-3] + '-' + str(x) for x in range(len(df))]
#       8     print('here')
# ----> 9     return df.apply(lambda x: pd.Series(eval(transforms), index = standard_schema), axis = 1)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    9421             kwargs=kwargs,
#    9422         )
# -> 9423         return op.apply().__finalize__(self, method="apply")
#    9424
#    9425     def applymap(
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply(self)
#     676             return self.apply_raw()
#     677
# --> 678         return self.apply_standard()
#     679
#     680     def agg(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#     796
#     797     def apply_standard(self):
# --> 798         results, res_index = self.apply_series_generator()
#     799
#     800         # wrap results
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     816                     # If we have a view on v, we need to make a copy because
#     817                     #  series_generator will swap out the underlying data
# --> 818                     results[i] = results[i].copy(deep=False)
#     819
#     820         return results, res_index
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in copy(self, deep)
#    6452         data = self._mgr.copy(deep=deep)
#    6453         self._clear_item_cache()
# -> 6454         return self._constructor(data).__finalize__(self, method="copy")
#    6455
#    6456     @final
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     384                 data = data.copy(deep=False)
#     385             # GH#33357 called with just the SingleBlockManager
# --> 386             NDFrame.__init__(self, data)
#     387             if fastpath:
#     388                 # e.g. from _box_col_values, skip validation of name
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __init__(self, data, copy, attrs)
#     279             attrs = dict(attrs)
#     280         object.__setattr__(self, "_attrs", attrs)
# --> 281         object.__setattr__(self, "_flags", Flags(self, allows_duplicate_labels=True))
#     282
#     283     @classmethod
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/flags.py in __init__(self, obj, allows_duplicate_labels)
#      49     def __init__(self, obj, *, allows_duplicate_labels) -> None:
#      50         self._allows_duplicate_labels = allows_duplicate_labels
# ---> 51         self._obj = weakref.ref(obj)
#      52
#      53     @property
#
# KeyboardInterrupt:

# %%
def get_urls(main_url):
    resource_ids = set()
    page = requests.get(main_url)
    soup = BeautifulSoup(page.content, "html.parser")
    for link in soup.find_all('a'):
        href = link.get('href')
        if href[:31] == 'https://data.wprdc.org/dataset/':
            resource_ids.add(href)
    return list(resource_ids)


pogoh_df = pd.DataFrame()

for resource in get_urls('https://data.wprdc.org/dataset/pogoh-trip-data'):
    pogoh_df = pd.concat([pogoh_df, get_trips(resource, pogoh_transforms)], ignore_index=True)
    print('finished ', resource, '\n', len(pogoh_df))

for resource in get_urls('https://data.wprdc.org/dataset/healthyride-trip-data'):
    try:
        pogoh_df = pd.concat([pogoh_df, get_trips(resource, healthyride_transforms)], ignore_index=True)
    except:
        print('Failed to scrape ' + resource)
    print('finished ', resource, '\n', len(pogoh_df))
# Out:
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/8e8a5cd9-943e-4d21-a7ed-05f865dd0038/download/apr-2023.xlsx
#  11351
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/1744cd4a-13cf-46de-b773-57f528ee9705/download/july-2022.xlsx
#  20427
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/2cd57068-5498-4b47-b2d3-512d3cdb1e0c/download/may-2022.xlsx
#  26546
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/e2c446b7-b0f5-43d5-87ac-f4b252f27aa3/download/july-2023.xlsx
#  44792
# finished  https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource